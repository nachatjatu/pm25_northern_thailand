# %% [markdown]
# <a href="https://colab.research.google.com/github/nachatjatu/pm25_northern_thailand/blob/main/vis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install rasterio fiona
import rasterio
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Collecting rasterio
#   Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting fiona
#   Downloading fiona-1.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 1.4 MB/s eta 0:00:00
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.11/dist-packages (from rasterio) (25.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from rasterio) (2025.1.31)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.11/dist-packages (from rasterio) (8.1.8)
# Collecting cligj>=0.5 (from rasterio)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.11/dist-packages (from rasterio) (2.0.2)
# Collecting click-plugins (from rasterio)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from rasterio) (3.2.1)
# Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 12.0 MB/s eta 0:00:00
# Downloading fiona-1.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 20.6 MB/s eta 0:00:00
# Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Installing collected packages: cligj, click-plugins, affine, rasterio, fiona
# Successfully installed affine-2.4.0 click-plugins-1.1.1 cligj-0.7.2 fiona-1.10.1 rasterio-1.4.3

# %%
# Open the GeoTIFF file
with rasterio.open('dataset_6_2020-03-25_7.tif') as src:
    print("Metadata:", src.meta)
    print("Number of Bands:", src.count)
    print("Dimensions (Height, Width):", (src.height, src.width))
    print("CRS:", src.crs)

    # Get the number of bands
    num_bands = src.count
    print("Number of Bands:", num_bands)

    # Get descriptions for each band (if available)
    band_names = [src.descriptions[i] if src.descriptions[i] else f'Band_{i+1}' for i in range(num_bands)]
    print("Band Names:", band_names)

    fig, axes = plt.subplots(2, 5)

    fig.set_figwidth(12)
    fig.set_figheight(5)

    for i in range(0, num_bands):
      band = src.read(i + 1)
    #   # Check statistics
    #   print("\nBand Statistics:")
    #   print("Min:", np.min(band), "Max:", np.max(band), "Mean:", np.mean(band))

      # Visualize
      axes[i // 5, i % 5].imshow(band, cmap='viridis')
      axes[i // 5, i % 5].set_title(f"{src.descriptions[i]}")
    plt.axis('off')
    plt.tight_layout()
    plt.show()
# Out:
# Metadata: {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 124, 'height': 124, 'count': 10, 'crs': CRS.from_wkt('PROJCS["WGS 84 / UTM zone 47N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",99],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32647"]]'), 'transform': Affine(1000.0, 0.0, 331000.0,
#        0.0, -1000.0, 2287000.0)}
# Number of Bands: 10
# Dimensions (Height, Width): (124, 124)
# CRS: EPSG:32647
# Number of Bands: 10
# Band Names: ['log_pm25_tdy', 'u_wind_10m', 'v_wind_10m', 'dew_temp_2m', 'temp_2m', 'surface_pressure', 'log_precip', 'log_max_frp', 'elevation', 'delta_pm25']

# %%
# Open the GeoTIFF file
with rasterio.open('dataset_5_2019-01-01_48.tif') as src:
    print("Metadata:", src.meta)
    print("Number of Bands:", src.count)
    print("Dimensions (Height, Width):", (src.height, src.width))
    print("CRS:", src.crs)

    # Get the number of bands
    num_bands = src.count
    print("Number of Bands:", num_bands)

    # Get descriptions for each band (if available)
    band_names = [src.descriptions[i] if src.descriptions[i] else f'Band_{i+1}' for i in range(num_bands)]
    print("Band Names:", band_names)

    for i in range(1, num_bands + 1):
      band = src.read(i)
      # Check statistics
      print("\nBand Statistics:")
      print("Min:", np.min(band), "Max:", np.max(band), "Mean:", np.mean(band))

      # Visualize
      plt.imshow(band, cmap='viridis')
      plt.colorbar()
      plt.title(f"Band {src.descriptions[i-1]} Visualization")
      plt.show()
# Out:
# Metadata: {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 128, 'height': 128, 'count': 10, 'crs': CRS.from_wkt('PROJCS["WGS 84 / UTM zone 47N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",99],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32647"]]'), 'transform': Affine(1000.0, 0.0, 708000.0,
#        0.0, -1000.0, 1972000.0)}
# Number of Bands: 10
# Dimensions (Height, Width): (128, 128)
# CRS: EPSG:32647
# Number of Bands: 10
# Band Names: ['Band_1', 'Band_2', 'Band_3', 'Band_4', 'Band_5', 'Band_6', 'Band_7', 'Band_8', 'Band_9', 'Band_10']
#
# Band Statistics:
# Min: 12.900001 Max: 24.2 Mean: 17.535328
# Band Statistics:
# Min: -1.8722174 Max: -0.5287599 Mean: -1.2031081
# Band Statistics:
# Min: -1.7155471 Max: 0.4161017 Mean: -0.6155504
# Band Statistics:
# Min: 284.2821 Max: 287.20572 Mean: 285.26157
# Band Statistics:
# Min: 289.14957 Max: 293.499 Mean: 291.4992
# Band Statistics:
# Min: 90618.17 Max: 100030.484 Mean: 96249.72
# Band Statistics:
# Min: 0.0 Max: 1.1938061e-05 Mean: 7.4601235e-07
# Band Statistics:
# Min: 0.0 Max: 2.8154087 Mean: 0.00017183891
# Band Statistics:
# Min: 135.0 Max: 1996.0 Mean: 503.18475
# Band Statistics:
# Min: -4.800001 Max: 8.099998 Mean: 1.6263244
